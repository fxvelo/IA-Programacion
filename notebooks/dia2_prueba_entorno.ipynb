# %% [markdown]
# # Día 2 - Prueba del entorno virtual
#
# Este notebook verifica que todo está funcionando correctamente.

# %%
import sys
print("Python version:", sys.version)
print("Entorno virtual:", sys.executable)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

print("NumPy version:", np.__version__)
print("Pandas version:", pd.__version__)
print("¡Todo funciona correctamente!")
